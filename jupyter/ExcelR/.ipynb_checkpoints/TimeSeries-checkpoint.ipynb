# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dx = pd.read_csv('../AirPassengers.xls')

# %%
dx
# Out:
#        Month  #Passengers
# 0    1949-01          112
# 1    1949-02          118
# 2    1949-03          132
# 3    1949-04          129
# 4    1949-05          121
# ..       ...          ...
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432
#
# [144 rows x 2 columns]

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(dx['#Passengers'], lags=50)
plt.show()

# %%
plot_pacf(dx['#Passengers'], lags=50)
plt.show()

# %%
idx = pd.to_datetime(dx['Month'])

# %%
dx.set_index(idx, inplace=True)

# %%
df = dx.drop('Month', axis=1)

# %%
df.rename(columns={'#Passengers': 'pass'}, inplace=True)

# %%
df['L2'] = df['pass'].shift(-2)

# %%
df
# Out:
#             pass     L1     L2
# Month
# 1949-01-01   112  118.0  132.0
# 1949-02-01   118  132.0  129.0
# 1949-03-01   132  129.0  121.0
# 1949-04-01   129  121.0  135.0
# 1949-05-01   121  135.0  148.0
# ...          ...    ...    ...
# 1960-08-01   606  508.0  461.0
# 1960-09-01   508  461.0  390.0
# 1960-10-01   461  390.0  432.0
# 1960-11-01   390  432.0    NaN
# 1960-12-01   432    NaN    NaN
#
# [144 rows x 3 columns]

# %%
ACF - 14
p ACF - 2

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
adfuller(df['pass'])[1]
# Out:
# 0.9918802434376409

# %%
d1 = df['pass'] - df['L1']

# %%
D1 = d1.dropna()

# %%
adfuller(D1)[1]
# Out:
# 0.05421329028382609

# %%
plt.plot(D1)

# %%
mod = ARIMA(df['pass'], order=(2,2,14)).fit()

# %%
yp = mod.predict(start='1958-08-01', end='1962-08-01')

# %%
plt.plot(df['pass'])
plt.plot(yp)

# %%
s1 = df['pass'] - df['pass'].shift(-12)

# %%
S1 = s1.dropna()

# %%
adfuller(S1)
# Out:
# (-3.3830207264924814,
#  0.011551493085514952,
#  1,
#  130,
#  {'1%': -3.4816817173418295,
#   '5%': -2.8840418343195267,
#   '10%': -2.578770059171598},
#  919.527129208137)

# %%
mdl = SARIMAX(df['pass'], order=(2,2,2), seasonal_order=(2,1,2,12)).fit()

# %%
Syp = mdl.predict(start='1958-08-01', end='1962-08-01')

# %%
plt.plot(df['pass'])
plt.plot(Syp)
