# %%
import pandas as pd
df = pd.read_csv('Q7.csv')

# %% [markdown]
# ### Mean, Median, Standard Diviation

# %%
df.describe()
# Out:
#           Points      Score      Weigh
# count  32.000000  32.000000  32.000000
# mean    3.596563   3.217250  17.848750
# std     0.534679   0.978457   1.786943
# min     2.760000   1.513000  14.500000
# 25%     3.080000   2.581250  16.892500
# 50%     3.695000   3.325000  17.710000
# 75%     3.920000   3.610000  18.900000
# max     4.930000   5.424000  22.900000

# %%
df.mode()
# Out:
#              Unnamed: 0  Points  Score  Weigh
# 0           AMC Javelin    3.07   3.44  17.02
# 1    Cadillac Fleetwood    3.92    NaN  18.90
# 2            Camaro Z28     NaN    NaN    NaN
# 3     Chrysler Imperial     NaN    NaN    NaN
# 4            Datsun 710     NaN    NaN    NaN
# 5      Dodge Challenger     NaN    NaN    NaN
# 6            Duster 360     NaN    NaN    NaN
# 7          Ferrari Dino     NaN    NaN    NaN
# 8              Fiat 128     NaN    NaN    NaN
# 9             Fiat X1-9     NaN    NaN    NaN
# 10       Ford Pantera L     NaN    NaN    NaN
# 11          Honda Civic     NaN    NaN    NaN
# 12       Hornet 4 Drive     NaN    NaN    NaN
# 13    Hornet Sportabout     NaN    NaN    NaN
# 14  Lincoln Continental     NaN    NaN    NaN
# 15         Lotus Europa     NaN    NaN    NaN
# 16        Maserati Bora     NaN    NaN    NaN
# 17            Mazda RX4     NaN    NaN    NaN
# 18        Mazda RX4 Wag     NaN    NaN    NaN
# ...

# %% [markdown]
# ### Median

# %%
df['Points'].median()
# Out:
# 3.6950000000000003

# %%
df['Score'].median()
# Out:
# 3.325

# %%
df['Weigh'].median()
# Out:
# 17.71

# %% [markdown]
# ### Variance

# %%
df['Points'].var()
# Out:
# 0.28588135080645166

# %%
df['Score'].var()
# Out:
# 0.9573789677419356

# %%
df['Weigh'].var()
# Out:
# 3.193166129032258

# %%
import scipy.stats as st
import matplotlib.pyplot as plt

# %%
ay = st.norm.pdf(df['Points'], df['Points'].mean(), df['Points'].std())

# %%
plt.plot(df['Points'],ay)

# %%
df.plot.line()
# Out:
# <Axes: >

# %%
df['Points'].plot.area()
# Out:
# <Axes: >

# %%
df['Score'].plot.area()
# Out:
# <Axes: >

# %%
df['Weigh'].plot.area()
# Out:
# <Axes: >

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot.pie(y='Points')
# Out:
# <Axes: ylabel='Points'>

# %%
df.plot.scatter('Points','Score',c=df['Weigh'])
# Out:
# <Axes: xlabel='Points', ylabel='Score'>

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df['Weigh'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
import seaborn as snb
import warnings
warnings.filterwarnings('ignore')
snb.distplot(df['Weigh'])
# Out:
# <Axes: xlabel='Weigh', ylabel='Density'>
