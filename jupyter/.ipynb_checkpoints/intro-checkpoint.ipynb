# %%
# command mode: blue mode
# edit mode: green mode
# command mode -> edit mode : Press Enter or you can click using mouse in the cell
# edit mode -> command mode : Press Esc

# Ctrl + Enter : can used to run or execute the whole chunk of code you have written in the cell
# You will see a change in [] when you execute any cell
# Ctrl + Enter can execute the code but it will not add or move to the next cell.

#while
# Shift + Enter : Execute the code and move to next cell

# %%
print("Hello World")
# Out:
# Hello World

# %%
# add any cell above this cell, you can use 'a' only when you are in command mode
# add any cell bellow this cell, you can use 'b' only when you are in command mode
# dd can be used to delete a cell only in command mode

# %%
import pandas as pd
df = pd.read_csv("customers-100.csv")
df
# Out:
#     Index      Customer Id First Name  Last Name  \
# 0       1  72e8E9e4463C89A      Ellen       Bush
# 1       2  03B8a96750a3DB6   Madeline  Mcfarland
# 2       3  A88cFF67cfb657b       Jack    Pittman
# 3       4  689cFdc5DfDa5aB   Meredith      Mckee
# 4       5  bA42d9F3fcF2f80     Angela   Bradshaw
# ..    ...              ...        ...        ...
# 95     96  514FB0b585658eF      Jamie      Doyle
# 96     97  3B3Ad17a8d1a8e4       Joan  Dominguez
# 97     98  776A477b8d3667b      Mason   Gonzalez
# 98     99  aEF66E8B21a7582     Rhonda       Buck
# 99    100  EaF00814FFA5DeA    Clinton      Cowan
#
#                             Company              City                 Country  \
# 0               Christian-Patterson      Clementsland              Cape Verde
# 1                      Schaefer LLC       Gregoryfort                  Sweden
# 2                      Le-Velazquez  North Colinshire  Bosnia and Herzegovina
# 3                       Pollard LLC         Dyershire                    Oman
# 4                  Gallagher-Conley          Annabury         North Macedonia
# ..                              ...               ...                     ...
# 95                    Mullen-Wright        Sheliafort             Afghanistan
# 96                      Lindsey Ltd       West Bianca                 Lebanon
# 97    Jacobson, Perkins and Marquez       Buckleyfort                   Congo
# 98  Mcclain, Strickland and Oconnor         Batesstad  British Virgin Islands
# 99                   Mcdaniel-Quinn          Billside                 Belarus
#
#                  Phone 1             Phone 2                           Email  \
# 0           665-274-9635  675-916-4120x42795  sanchezkaitlyn@mann-fisher.org
# 1       001-981-200-8019        707.632.9351             zbarnett@mathis.com
# 2          (343)295-0482        963-844-4387      pettygeorge@novak-wolf.com
# 3          (776)510-1203        706.952.8037     jweaver@finley-faulkner.com
# 4   001-745-613-7845x668        449.816.8470       diamondcooke@friedman.com
# ..                   ...                 ...                             ...
# 95   (779)237-6017x75856        296.657.4582        pgiles@combs-garrett.com
# 96    563-809-4359x25133       (343)325-0168               sjensen@logan.com
# 97          336-980-0351    001-906-949-5820          ymiranda@cervantes.com
# 98          668.693.3913       (810)431-5150             cody07@shepherd.biz
# 99     (572)916-8797x342   992.924.0351x1803          maysgloria@edwards.com
#
#    Subscription Date                           Website
# 0         2020-11-06                http://daniel.com/
# 1         2021-10-02           https://www.walker.com/
# 2         2021-04-20             http://www.kline.com/
# 3         2021-02-19                http://obrien.biz/
# 4         2023-02-24       http://haynes-benjamin.com/
# ..               ...                               ...
# 95        2022-07-16  http://www.castaneda-sutton.com/
# 96        2022-03-12                https://payne.com/
# 97        2023-05-16            http://www.bowers.com/
# 98        2021-05-29    http://www.robertson-neal.com/
# 99        2021-09-30              https://webster.net/
#
# [100 rows x 12 columns]
